# %%
# !pip install dtreeviz
#plz install above module

# %% [markdown]
# ## Setup

# %%
from sklearn.datasets import *
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

import dtreeviz
import graphviz.backend as be
from IPython.display import Image, display_svg, SVG
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Load Sample Data

# %%
iris = load_iris()

X_train = iris.data
y_train = iris.target
# Out:
# DecisionTreeClassifier()

# %%
clas = DecisionTreeClassifier()  
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
observation = [[ 5, 4, 3, 2]] # Predict observation's class
clas.predict(observation)
clas.predict_proba(observation)
# Out:
# array([[0., 1., 0.]])

# %%
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# #1 Classification
# ### Initialize dtreeviz model (adaptor)
# To adapt dtreeviz to a specific model, use the model() function to get an adaptor. You'll need to provide the model, X/y data, feature names, target name, and target class names:

# %%
viz = dtreeviz.model(clas, X_train, y_train, feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz

# %% [markdown]
# We'll use this model to demonstrate dtreeviz functionality in the following sections; the code will look the same for any decision tree library once we have this model adaptor.

# %% [markdown]
# # Tree structure visualizations
# To show the decision tree structure using the default visualization, call view():

# %%
viz.view(scale=1)

# %% [markdown]
# To change the visualization, you can pass parameters, such as changing the orientation to left-to-right:

# %%
viz.view(orientation="LR")

# %% [markdown]
# # Without Any graphs
# To visualize larger trees, you can reduce the amount of detail by turning off the fancy view:

# %%
viz.view(fancy=False)

# %% [markdown]
# Another way to reduce the visualization size is to specify the tree depths of interest:
#
#
#
# ---

# %%
viz.view(depth_range_to_display=(1, 2)) # root is level 0

# %% [markdown]
# ## Show node number

# %%
viz.view(show_node_labels=True,orientation='LR')

# %% [markdown]
# # Leaf info
# There are a number of functions to get information about the leaves of the tree.

# %%
viz.leaf_sizes(figsize=(5,4))

# %%
viz.ctree_leaf_distributions(figsize=(3.5,3))

# %%
viz.node_stats(node_id=6)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count                1.0               1.0                1.0
# mean                 4.9               2.5                4.5
# std                  NaN               NaN                NaN
# min                  4.9               2.5                4.5
# 25%                  4.9               2.5                4.5
# 50%                  4.9               2.5                4.5
# 75%                  4.9               2.5                4.5
# max                  4.9               2.5                4.5
#
#        petal width (cm)
# count               1.0
# mean                1.7
# std                 NaN
# min                 1.7
# 25%                 1.7
# 50%                 1.7
# 75%                 1.7
# max                 1.7

# %% [markdown]
# ## 2. Regression

# %%
regr = DecisionTreeRegressor(max_depth=1)
boston = load_boston()

X_train = boston.data
y_train = boston.target
regr.fit(X_train, y_train)

viz1 = dtreeviz.model(regr,X_train,y_train, target_name='price',
               feature_names=boston.feature_names)
viz1

# %%
  viz1.view(scale=3)

# %%
viz1.view(orientation="LR",scale=3)

# %%
viz1.view(fancy=False,scale=2)

# %%
viz1.rtree_leaf_distributions(figsize=(3.5,4))
